# %% [markdown]
# <a href="https://colab.research.google.com/github/Blane187/Advanced-RVC-Inference/blob/master/Advanced_RVC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown # Check GPU
# !nvidia-smi

# %%
#@markdown #  Install Dependencies
# !apt-get update
# !apt-get install -qq -y aria2
# !git clone -b master https://github.com/Blane187/Blane-RVC
# !pip install -r /content/Blane-RVC/requirements.txt

# %%
#@markdown # Download models
# !python /content/Blane-RVC/tools/Download_models.py

# %%
#@markdown # Run
# %cd /content/Blane-RVC
# !python app.py --colab

# %% [markdown]
# thanks to [ArkanDash](https://github.com/ArkanDash)
