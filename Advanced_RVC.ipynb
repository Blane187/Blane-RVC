# %% [markdown]
# <a href="https://colab.research.google.com/github/Blane187/Advanced-RVC-Inference/blob/master/Advanced_RVC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown # Check GPU
# !nvidia-smi

# %%
#@markdown #  Install Dependencies
# !apt-get update
# !apt-get install -qq -y aria2
# !git clone -b master https://github.com/Blane187/Advanced-RVC-Inference
# !pip install -r /content/Advanced-RVC-Inference/requirements.txt

# %%
#@markdown # Download models
# !python /content/Advanced-RVC-Inference/tools/Download_models.py

# %%
#@markdown # Run
# %cd /content/Advanced-RVC-Inference
# !python infer.py --colab

# %% [markdown]
# advanced RVC inference by [ArkanDash](https://github.com/ArkanDash/Advanced-RVC-Inference)
